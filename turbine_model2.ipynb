# %%
pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (9.8.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from IPython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from jedi>=0.18.1->IPython) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from stack_data>=0.6.0->IPython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from stack_data>=0.6.0->IPython) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\hp\pycharmprojects\uniosun_project\.venv\lib\site-packages (from stack_data>=0.6.0->IPython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
from datetime import datetime, timedelta

# ── CONFIG ───────────────────────────────────────────────────────
INPUT_FILE = r"C:\Users\hp\Downloads\GT1 Turbine Data Log Sheet for July 2025.xlsx"

DESCRIPTION = {
    "COMPRESSOR INLET PRESSURE": "CIP",
    "COMPRESSOR INLET AIR TEMP": "CIT",
    "COMPRESSOR DISCHARGE PRESSURE": "CDP",
    "COMPRESSOR DISCHARGE TEMPERATURE": "CDT",
    "IGV POSITION": "IGV_Position",
    "FILTER DIFFERENTIAL PRESSURE": "Filter_DP",
    "MAXIMUM VIBRATION": "VIB",
    "GT SPEED": "GT_Speed",
    "LOAD": "Load"
}

# Normalize lookup dict (upper case)
DESCRIPTION_NORMALIZED = {k.upper(): v for k, v in DESCRIPTION.items()}

# ── PROCESS ALL SHEETS ───────────────────────────────────────────
all_records = []

xls = pd.ExcelFile(INPUT_FILE)

for sheet_name in xls.sheet_names:
    try:
        sheet_date = pd.to_datetime(sheet_name.strip(), format="%d-%m-%Y", errors='coerce')
        if pd.isna(sheet_date):
            print(f"Skipped sheet (invalid date): {sheet_name}")
            continue
    except:
        print(f"Skipped sheet (error parsing date): {sheet_name}")
        continue

    # Read the sheet
    df_raw = pd.read_excel(xls, sheet_name=sheet_name, header=3)

    print(f"\n=== Sheet: {sheet_name} ===")
    print("Shape:", df_raw.shape)
    print("Columns (first 10):", df_raw.columns.tolist()[:10])

    # ── Check for DESCRIPTION column ───────────────────────────────
    if "DESCRIPTION" not in df_raw.columns:
        print("!!! CRITICAL: 'DESCRIPTION' column NOT FOUND in", sheet_name)
        print("   → Skipping this sheet")
        continue   # ← Now this is correct: skips to next sheet

    # If we reach here → DESCRIPTION column exists
    print("Found 'DESCRIPTION' column → processing...")

    # Clean DESCRIPTION column
    df_raw["DESCRIPTION"] = (
        df_raw["DESCRIPTION"]
        .astype(str)
        .str.strip()
        .str.upper()
    )

    # Filter only known parameters
    mask = df_raw["DESCRIPTION"].isin(DESCRIPTION_NORMALIZED.keys())
    df_params = df_raw[mask].copy()

    if df_params.empty:
        print(f"No matching parameters found in sheet: {sheet_name}")
        continue

    # Map to short names
    df_params["Parameter"] = df_params["DESCRIPTION"].map(DESCRIPTION_NORMALIZED)

    # Select hour columns (safely)
    if len(df_raw.columns) < 31:
        print(f"Warning: Only {len(df_raw.columns)} columns found → using from index 7 onward")
        hour_columns = df_params.columns[7:]
    else:
        hour_columns = df_params.columns[7:31]

    # Create records
    for _, row in df_params.iterrows():
        param = row["Parameter"]
        for i, col in enumerate(hour_columns):
            try:
                value = float(row[col])
                if pd.isna(value):
                    continue
            except (ValueError, TypeError):
                continue

            timestamp = sheet_date.replace(hour=0, minute=0, second=0, microsecond=0) + timedelta(hours=i)

            all_records.append({
                "Date": sheet_date.date(),
                "Timestamp": timestamp,
                "Parameter": param,
                "Value": value
            })
# ── Final DataFrame ──────────────────────────────────────────────
df_long = pd.DataFrame(all_records)

if df_long.empty:
    print("No valid data found across all sheets!")
else:
    # Sort for readability
    df_long = df_long.sort_values(["Parameter", "Timestamp"]).reset_index(drop=True)

    # Convert Value to numeric (just in case)
    df_long["Value"] = pd.to_numeric(df_long["Value"], errors='coerce')

    print(f"Total records: {len(df_long):,}")
    print(df_long.head(30))

    # Save long format (best for most analyses and ML)
    df_long.to_csv("GT1_Compressor_Long_Format_2025.csv", index=False)
    df_long.to_excel("GT1_Compressor_Long_Format_2025.xlsx", index=False)

    # Optional: Wide format (one column per parameter)
    df_wide = df_long.pivot_table(
        index="Timestamp",
        columns="Parameter",
        values="Value"
    ).reset_index()

    # Make sure all expected columns exist
    for param in DESCRIPTION.values():
        if param not in df_wide.columns:
            df_wide[param] = pd.NA

    # Order columns nicely
    df_wide = df_wide[['Timestamp'] + list(DESCRIPTION.values())]

    df_wide.to_csv("GT1_Compressor_Wide_Format_2025.csv", index=False)
    df_wide.to_excel("GT1_Compressor_Wide_Format_2025.xlsx", index=False)

    print("\nWide format preview:")
    print(df_wide.head())
# Out:
# Skipped sheet (invalid date): 01-07 -2025
# Skipped sheet (invalid date): 02-0 7-2025
#
# === Sheet: 03-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 04-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 05-07-2025  ===
# Shape: (1048572, 41)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 06-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 07-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 08-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 09-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 10-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 11-07-2025  ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 12-07-2025   ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 13-07-2025   ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 14-07-2025   ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 15-07-2025   ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 16-07-2025   ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 17-07-2025   ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 18-07-2025    ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 19-07-2025    ===
# Shape: (47, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 20-07-2025 ===
# Shape: (31, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 21-07-2025 ===
# Shape: (31, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
#
# === Sheet: 22-07-2025 ===
# Shape: (31, 31)
# Columns (first 10): ['SUB SYSTEM', 'DESCRIPTION', 'KKS', 'UNIT', 'RANGE', 'ALARM', 'TRIP', datetime.time(0, 0), datetime.time(1, 0), datetime.time(2, 0)]
# Found 'DESCRIPTION' column → processing...
# Total records: 2,452
#           Date           Timestamp Parameter  Value
# 0   2025-07-03 2025-07-03 00:00:00       CDP    9.0
# 1   2025-07-03 2025-07-03 01:00:00       CDP    9.0
# 2   2025-07-03 2025-07-03 02:00:00       CDP    8.0
# 3   2025-07-03 2025-07-03 03:00:00       CDP    8.0
# 4   2025-07-03 2025-07-03 17:00:00       CDP    8.0
# 5   2025-07-03 2025-07-03 18:00:00       CDP    9.0
# 6   2025-07-03 2025-07-03 19:00:00       CDP   10.0
# 7   2025-07-03 2025-07-03 20:00:00       CDP   10.0
# 8   2025-07-03 2025-07-03 21:00:00       CDP   10.0
# 9   2025-07-03 2025-07-03 22:00:00       CDP   10.0
# 10  2025-07-03 2025-07-03 23:00:00       CDP   10.0
# 11  2025-07-04 2025-07-04 00:00:00       CDP   10.0
# 12  2025-07-04 2025-07-04 01:00:00       CDP    8.0
# 13  2025-07-04 2025-07-04 02:00:00       CDP    8.0
# 14  2025-07-04 2025-07-04 03:00:00       CDP    8.0
# 15  2025-07-04 2025-07-04 04:00:00       CDP    8.0
# 16  2025-07-04 2025-07-04 05:00:00       CDP    9.0
# 17  2025-07-04 2025-07-04 06:00:00       CDP    9.0
# 18  2025-07-04 2025-07-04 07:00:00       CDP    9.0
# 19  2025-07-04 2025-07-04 08:00:00       CDP    9.0
# 20  2025-07-04 2025-07-04 09:00:00       CDP    9.0
# 21  2025-07-04 2025-07-04 10:00:00       CDP    9.0
# 22  2025-07-04 2025-07-04 11:00:00       CDP   10.0
# 23  2025-07-04 2025-07-04 12:00:00       CDP   10.0
# 24  2025-07-04 2025-07-04 13:00:00       CDP   10.0
# 25  2025-07-04 2025-07-04 14:00:00       CDP   10.0
# 26  2025-07-04 2025-07-04 15:00:00       CDP    9.0
# 27  2025-07-04 2025-07-04 16:00:00       CDP    9.0
# 28  2025-07-04 2025-07-04 17:00:00       CDP   10.0
# 29  2025-07-04 2025-07-04 18:00:00       CDP   10.0
#
# Wide format preview:
# Parameter           Timestamp    CIP   CIT  CDP    CDT  IGV_Position  \
# 0         2025-07-03 00:00:00  128.6  24.0  9.0  335.0          63.0
# 1         2025-07-03 01:00:00  124.2  24.0  9.0  333.0          61.0
# 2         2025-07-03 02:00:00  123.3  24.0  8.0  328.0          58.0
# 3         2025-07-03 03:00:00  123.3  24.0  8.0  327.0          57.0
# 4         2025-07-03 17:00:00  101.2  25.0  8.0  331.0          57.0
#
# Parameter  Filter_DP  VIB  GT_Speed  Load
# 0              171.3  4.5    3019.0  95.1
# 1              171.2  4.3    3020.0  94.6
# 2              168.8  4.3    3014.0  99.2
# 3              166.9  4.1    3013.0  84.9
# 4              137.1  4.1    3032.0  89.1

# %%
df_wide["CIP"] = df_wide["CIP"].dropna()
df_wide["CIP"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 281 entries, 0 to 280
# Series name: CIP
# Non-Null Count  Dtype
# --------------  -----
# 281 non-null    float64
# dtypes: float64(1)
# memory usage: 2.3 KB

# %%
df_wide.to_csv("GT1_Compressor_Wide_Format_2025.csv", index=False)

# %%
result = pd.read_csv("GT1_Compressor_Wide_Format_2025.csv")

# %%
print(result)
# Out:
#                Timestamp    CIP   CIT   CDP    CDT  IGV_Position  Filter_DP  \
# 0    2025-07-03 00:00:00  128.6  24.0   9.0  335.0          63.0      171.3
# 1    2025-07-03 01:00:00  124.2  24.0   9.0  333.0          61.0      171.2
# 2    2025-07-03 02:00:00  123.3  24.0   8.0  328.0          58.0      168.8
# 3    2025-07-03 03:00:00  123.3  24.0   8.0  327.0          57.0      166.9
# 4    2025-07-03 17:00:00  101.2  25.0   8.0  331.0          57.0      137.1
# ..                   ...    ...   ...   ...    ...           ...        ...
# 276  2025-07-22 19:00:00  101.6  27.0  10.0  359.0          86.0        NaN
# 277  2025-07-22 20:00:00  108.5  25.0  10.0  358.0          86.0        NaN
# 278  2025-07-22 21:00:00  105.2  25.0   9.0  356.0          85.0        NaN
# 279  2025-07-22 22:00:00  110.4  25.0  10.0  359.0          86.0        NaN
# 280  2025-07-22 23:00:00  115.4  25.0  10.0  345.0          72.0        NaN
#
#      GT_Speed   Load
# 0      3019.0   95.1
# 1      3020.0   94.6
# 2      3014.0   99.2
# 3      3013.0   84.9
# 4      3032.0   89.1
# ..        ...    ...
# 276    3009.0  108.6
# 277    3009.0  109.9
# 278    3008.0   98.7
# 279    3010.0  109.6
# 280    3017.0  103.4
#
# [281 rows x 9 columns]

# %%
# Out:
# 0       9.0
# 1       9.0
# 2       8.0
# 3       8.0
# 4       8.0
#        ...
# 276    10.0
# 277    10.0
# 278     9.0
# 279    10.0
# 280    10.0
# Name: CDP, Length: 281, dtype: float64

# %%
result["Filter_DP"].dropna()
# Out:
# 0      171.3
# 1      171.2
# 2      168.8
# 3      166.9
# 4      137.1
#        ...
# 252    161.5
# 253    164.1
# 254    121.5
# 255    167.5
# 256    164.7
# Name: Filter_DP, Length: 257, dtype: float64
